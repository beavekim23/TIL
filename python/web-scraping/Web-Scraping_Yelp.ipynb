# %% [markdown]
# # Top 30 Restaurants in LA, SF, and NY
# ## Scrape Yelp.com

# %%
from selenium import webdriver
from time import sleep
ch_driver = webdriver.Chrome('C:/Users/beave/AppData/Roaming/Microsoft/Windows/Start Menu/Programs/Python 3.7/chromedriver.exe')

ch_driver.implicitly_wait(5) 

yelp_url = 'https://www.yelp.com/'
ch_driver.get(yelp_url)

# %%
search_input = ch_driver.find_element_by_id('find_desc')
search_input.send_keys('restaurants')
city_input = ch_driver.find_element_by_id('dropperText_Mast')
city_input.click()
city_input.send_keys('los angeles')

search_button = ch_driver.find_element_by_id('header-search-submit')
search_button.click()

# %% [markdown]
# ### Practice

# %%
r_path = '//*[@id="wrap"]/div[3]/div[2]/div[2]/div/div[1]/div[1]/div/ul/li/div/div/div/div/div[2]/div[1]/div[1]/div[1]'
restaurants = ch_driver.find_elements_by_xpath(r_path)

# %%
# get title, name, link
title = restaurants[0].find_element_by_tag_name('h3').text
name = restaurants[0].find_element_by_tag_name('a').text
link = restaurants[0].find_element_by_tag_name('a').get_attribute('href')

print(title, name, link)
# Out:
# Ad
# Taste of India - Sherman Oaks Taste of India - Sherman Oaks https://www.yelp.com/adredir?ad_business_id=7rio_T3BIJhmoOA3NiFasQ&campaign_id=HJwYYCZfNdkFUTskx4OlHQ&click_origin=search_results&placement=above_search&redirect_url=https%3A%2F%2Fwww.yelp.com%2Fbiz%2Ftaste-of-india-sherman-oaks-sherman-oaks&request_id=3ce31d9080c0c0d4&signature=14ce024614c390acde12bb0e310d91f9c4ff552475895dbd7a2751283d74d583&slot=0

# %%
# get rating
#//*[@id="wrap"]/div[3]/div[2]/div[2]/div/div[1]/div[1]/div/ul/li[4]/div/div/div/div/div[2]/div[1]/div[1]/div[1]/div[2]/span/div
divs = restaurants[0].find_elements_by_tag_name('div')

rating_span = divs[1].find_element_by_tag_name('span')
rating_div = rating_span.find_element_by_tag_name('div')
rating = rating_div.get_attribute('aria-label')
rating
# Out:
# '4 star rating'

# %%
#get number of reviews
#//*[@id="wrap"]/div[3]/div[2]/div[2]/div/div[1]/div[1]/div/ul/li[4]/div/div/div/div/div[2]/div[1]/div[1]/div[1]/div[3]/span
review_span = divs[3].find_element_by_tag_name('span')
review = review_span.text
review
# Out:
# '386 reviews'

# %%
#get price index and keyword
try:
    pk_elem = divs[4].find_elements_by_tag_name('span')
    price = pk_elem[0].text
    keyword = pk_elem[1].text
except IndexError:
    pk_elem = divs[4].find_element_by_tag_name('span')
    price = "N/A"
    keyword = pk_elem.text
    
print(price, keyword)
# Out:
# $$ Indian

# %% [markdown]
# ### Start a Project

# %%
def get_restaurant_list():
    result_list = []
   
    r_path = '//*[@id="wrap"]/div[3]/div[2]/div[2]/div/div[1]/div[1]/div/ul/li/div/div/div/div/div[2]/div[1]/div[1]/div[1]'
    restaurants = ch_driver.find_elements_by_xpath(r_path)
    for i,item in enumerate(restaurants):
        title = item.find_element_by_tag_name('h3').text
        name = item.find_element_by_tag_name('a').text
        link = item.find_element_by_tag_name('a').get_attribute('href')
        
        divs = item.find_elements_by_tag_name('div')
        
        #get rating
        rating_span = divs[1].find_element_by_tag_name('span')
        rating_div = rating_span.find_element_by_tag_name('div')
        rating = rating_div.get_attribute('aria-label')
        
        #get the number of reivews
        review_span = divs[3].find_element_by_tag_name('span')
        review = review_span.text
        
        #get price index and keywords
        try:
            pk_elem = divs[4].find_elements_by_tag_name('span')
            price = pk_elem[0].text
            keyword = pk_elem[1].text
        except IndexError:
            pk_elem = divs[4].find_element_by_tag_name('span')
            price = "N/A"
            keyword = pk_elem.text
        
        #remove ads
        if title[0].isdigit() == False:
            continue
            
        result_list.append([name, link, rating, review, price, keyword])
        
    return result_list

# %%
def get_restaurants():
    result = {}
    result_list = get_restaurant_list()
    
    for i in range(30):
        result[str(i+1)] = (result_list[i])
        
    return result

# %%
all_result = {}
all_result['Los Angeles'] = get_restaurants()
sleep(5)

city_list = ['San Francisco', 'New York']

for city in city_list:
    #search another city
    another_city = ch_driver.find_element_by_id('search_location')
    another_city.click()
    another_city.send_keys(city)
    another_button = ch_driver.find_element_by_xpath('//*[@id="header_find_form"]/div/div[2]/div/div[2]/button')
    another_button.click()
    
    #append it to all_result
    all_result[city] = get_restaurants()
    sleep(5)

# %%
all_result
# Out:
# {'Los Angeles': {'1': ['Bestia',
#    'https://www.yelp.com/biz/bestia-los-angeles?osq=restaurants',
#    '4.5 star rating',
#    '5368 reviews',
#    '$$$',
#    'Italian, Cocktail Bars, Pizza'],
#   '2': ['Howlin’ Ray’s',
#    'https://www.yelp.com/biz/howlin-rays-los-angeles-3?osq=restaurants',
#    '4.5 star rating',
#    '4352 reviews',
#    '$$',
#    'Southern, Chicken Shop, American (Traditional)'],
#   '3': ['Running Goose',
#    'https://www.yelp.com/biz/running-goose-los-angeles?osq=restaurants',
#    '4.5 star rating',
#    '768 reviews',
#    '$$',
#    'Tapas/Small Plates, Gastropubs, Latin American'],
#   '4': ['République',
#    'https://www.yelp.com/biz/r%C3%A9publique-los-angeles-2?osq=restaurants',
#    '4 star rating',
#    '4495 reviews',
#    '$$',
#    'French, Breakfast & Brunch, Cocktail Bars'],
#   '5': ['RockSugar Southeast Asian Kitchen',
#    'https://www.yelp.com/biz/rocksugar-southeast-asian-kitchen-los-angeles?osq=restaurants',
#    '4 star rating',
#    '2199 reviews',
#    '$$',
#    'Indonesian, Vietnamese, Malaysian'],
#   '6': ['The Morrison',
#    'https://www.yelp.com/biz/the-morrison-los-angeles?osq=restaurants',
#    '4.5 star rating',
#    '3906 reviews',
#    '$$',
#    'Gastropubs, Burgers, Bars'],
#   '7': ['Bao Dim Sum House',
#    'https://www.yelp.com/biz/bao-dim-sum-house-los-angeles?osq=restaurants',
#    '4 star rating',
#    '2429 reviews',
#    '$$',
#    'Dim Sum, Bars, Tapas/Small Plates'],
#   '8': ['Slurpin’ Ramen Bar',
#    'https://www.yelp.com/biz/slurpin-ramen-bar-los-angeles?osq=restaurants',
#    '4.5 star rating',
#    '3216 reviews',
#    '$$',
#    'Ramen, Noodles'],
#   '9': ['Dirt Dog',
#    'https://www.yelp.com/biz/dirt-dog-los-angeles-4?osq=restaurants',
#    '4.5 star rating',
#    '1523 reviews',
#    '$',
#    'Hot Dogs, Beer Bar'],
#   '10': ['Daikokuya Little Tokyo',
#    'https://www.yelp.com/biz/daikokuya-little-tokyo-los-angeles?osq=restaurants',
#    '4 star rating',
#    '7888 reviews',
#    '$$',
#    'Ramen, Noodles'],
#   '11': ['Perch',
#    'https://www.yelp.com/biz/perch-los-angeles?osq=restaurants',
#    '4 star rating',
#    '6418 reviews',
#    '$$$',
#    'Lounges, French'],
#   '12': ['Yup Dduk La',
#    'https://www.yelp.com/biz/yup-dduk-la-los-angeles?osq=restaurants',
#    '4.5 star rating',
#    '1775 reviews',
#    '$$',
#    'Korean'],
#   '13': ['Eataly',
#    'https://www.yelp.com/biz/eataly-los-angeles-6?osq=restaurants',
#    '3.5 star rating',
#    '1556 reviews',
#    '$$',
#    'Specialty Food, Italian, Food Court'],
#   '14': ['Han Bat Sul Lung Tang',
#    'https://www.yelp.com/biz/han-bat-sul-lung-tang-los-angeles-2?osq=restaurants',
#    '4.5 star rating',
#    '1918 reviews',
#    '$',
#    'Korean, Comfort Food, Soup'],
#   '15': ['Marugame Monzo',
#    'https://www.yelp.com/biz/marugame-monzo-los-angeles-2?osq=restaurants',
#    '4.5 star rating',
#    '3173 reviews',
#    '$$',
#    'Japanese, Noodles, Asian Fusion'],
#   '16': ['Genwa Korean BBQ',
#    'https://www.yelp.com/biz/genwa-korean-bbq-los-angeles-2?osq=restaurants',
#    '4.5 star rating',
#    '2663 reviews',
#    '$$',
#    'Korean, Barbeque, Soup'],
#   '17': ['Kang Ho-dong Baekjeong',
#    'https://www.yelp.com/biz/kang-ho-dong-baekjeong-los-angeles-4?osq=restaurants',
#    '4.5 star rating',
#    '3918 reviews',
#    '$$',
#    'Barbeque, Korean'],
#   '18': ['Eggslut',
#    'https://www.yelp.com/biz/eggslut-los-angeles-7?osq=restaurants',
#    '4 star rating',
#    '5273 reviews',
#    '$',
#    'Breakfast & Brunch'],
#   '19': ['Bottega Louie',
#    'https://www.yelp.com/biz/bottega-louie-los-angeles?osq=restaurants',
#    '4 star rating',
#    '15824 reviews',
#    '$$',
#    'Italian, Bakeries, Breakfast & Brunch'],
#   '20': ['Pasta Sisters',
#    'https://www.yelp.com/biz/pasta-sisters-los-angeles?osq=restaurants',
#    '4.5 star rating',
#    '1128 reviews',
#    '$$',
#    'Delis, Italian'],
#   '21': ['The Little Door',
#    'https://www.yelp.com/biz/the-little-door-los-angeles?osq=restaurants',
#    '4 star rating',
#    '1925 reviews',
#    '$$$',
#    'French, Mediterranean, Modern European'],
#   '22': ['Corn Man',
#    'https://www.yelp.com/biz/corn-man-los-angeles-3?osq=restaurants',
#    '4.5 star rating',
#    '822 reviews',
#    '$',
#    'Food Stands, Mexican'],
#   '23': ['Wurstküche',
#    'https://www.yelp.com/biz/wurstk%C3%BCche-los-angeles-2?osq=restaurants',
#    '4 star rating',
#    '7923 reviews',
#    '$$',
#    'Hot Dogs, German, Gastropubs'],
#   '24': ['Sun Nong Dan',
#    'https://www.yelp.com/biz/sun-nong-dan-los-angeles-4?osq=restaurants',
#    '4.5 star rating',
#    '1187 reviews',
#    '$$',
#    'Korean, Soup'],
#   '25': ['Osteria Mamma',
#    'https://www.yelp.com/biz/osteria-mamma-los-angeles?osq=restaurants',
#    '4 star rating',
#    '1395 reviews',
#    '$$',
#    'Italian, Wine Bars'],
#   '26': ['Dave’s Hot Chicken',
#    'https://www.yelp.com/biz/daves-hot-chicken-los-angeles?osq=restaurants',
#    '4.5 star rating',
#    '1250 reviews',
#    '$$',
#    'Chicken Shop'],
#   '27': ['Hangari Bajirak Kalguksu',
#    'https://www.yelp.com/biz/hangari-bajirak-kalguksu-los-angeles?osq=restaurants',
#    '4.5 star rating',
#    '1322 reviews',
#    '$$',
#    'Korean, Soup, Noodles'],
#   '28': ['L’Assiette Steak Frites',
#    'https://www.yelp.com/biz/l-assiette-steak-frites-los-angeles-2?osq=restaurants',
#    '4 star rating',
#    '626 reviews',
#    '$$',
#    'Steakhouses, French, Wine Bars'],
#   '29': ['Franco’s',
#    'https://www.yelp.com/biz/francos-los-angeles?osq=restaurants',
#    '4 star rating',
#    '1096 reviews',
#    '$$',
#    'Italian, Steakhouses, Seafood'],
#   '30': ['Dumpling House',
#    'https://www.yelp.com/biz/dumpling-house-los-angeles-2?osq=restaurants',
#    '4.5 star rating',
#    '429 reviews',
#    '$',
#    'Korean']},
#  'San Francisco': {'1': ['Fog Harbor Fish House',
#    'https://www.yelp.com/biz/fog-harbor-fish-house-san-francisco-2?osq=restaurants',
#    '4 star rating',
#    '4878 reviews',
#    '$$',
#    'Seafood, Bars'],
#   '2': ['Marufuku Ramen SF',
#    'https://www.yelp.com/biz/marufuku-ramen-sf-san-francisco?osq=restaurants',
#    '4.5 star rating',
#    '1767 reviews',
#    '$$',
#    'Ramen'],
#   '3': ['The House',
#    'https://www.yelp.com/biz/the-house-san-francisco?osq=restaurants',
#    '4.5 star rating',
#    '4479 reviews',
#    '$$$',
#    'Asian Fusion'],
#   '4': ['The Codmother Fish and Chips',
#    'https://www.yelp.com/biz/the-codmother-fish-and-chips-san-francisco-3?osq=restaurants',
#    '4.5 star rating',
#    '2773 reviews',
#    '$',
#    'British, Fish & Chips, Seafood'],
#   '5': ['Farmhouse Kitchen Thai Cuisine',
#    'https://www.yelp.com/biz/farmhouse-kitchen-thai-cuisine-san-francisco?osq=restaurants',
#    '4 star rating',
#    '1630 reviews',
#    '$$',
#    'Thai, Comfort Food'],
#   '6': ['Liholiho Yacht Club',
#    'https://www.yelp.com/biz/liholiho-yacht-club-san-francisco-2?osq=restaurants',
#    '4.5 star rating',
#    '1981 reviews',
#    '$$$',
#    'Bars, American (New), Seafood'],
#   '7': ['Mersea',
#    'https://www.yelp.com/biz/mersea-san-francisco-2?osq=restaurants',
#    '4.5 star rating',
#    '344 reviews',
#    '$$',
#    'American (Traditional), Bars'],
#   '8': ['Scoma’s Restaurant',
#    'https://www.yelp.com/biz/scomas-restaurant-san-francisco-3?osq=restaurants',
#    '4 star rating',
#    '3331 reviews',
#    '$$$',
#    'Seafood, Italian, Lounges'],
#   '9': ['Izakaya KOU',
#    'https://www.yelp.com/biz/izakaya-kou-san-francisco-2?osq=restaurants',
#    '4 star rating',
#    '706 reviews',
#    '$$',
#    'Tapas/Small Plates, Lounges, Izakaya'],
#   '10': ['Hog Island Oyster Co',
#    'https://www.yelp.com/biz/hog-island-oyster-co-san-francisco?osq=restaurants',
#    '4.5 star rating',
#    '5477 reviews',
#    '$$',
#    'Seafood, Seafood Markets, Live/Raw Food'],
#   '11': ['Barrel Head Brewhouse',
#    'https://www.yelp.com/biz/barrel-head-brewhouse-san-francisco-5?osq=restaurants',
#    '4 star rating',
#    '496 reviews',
#    '$$',
#    'Breweries, American (Traditional), Venues & Event Spaces'],
#   '12': ['Loló',
#    'https://www.yelp.com/biz/lol%C3%B3-san-francisco-4?osq=restaurants',
#    '4 star rating',
#    '1955 reviews',
#    '$$',
#    'Tapas/Small Plates'],
#   '13': ['Mensho Tokyo',
#    'https://www.yelp.com/biz/mensho-tokyo-san-francisco-2?osq=restaurants',
#    '4 star rating',
#    '1799 reviews',
#    '$$',
#    'Ramen, Noodles'],
#   '14': ['Sotto Mare Oysteria & Seafood',
#    'https://www.yelp.com/biz/sotto-mare-oysteria-and-seafood-san-francisco?osq=restaurants',
#    '4.5 star rating',
#    '3307 reviews',
#    '$$',
#    'Seafood, Italian, Bars'],
#   '15': ['Tacorea',
#    'https://www.yelp.com/biz/tacorea-san-francisco?osq=restaurants',
#    '4.5 star rating',
#    '1298 reviews',
#    '$',
#    'Mexican, Korean, Latin American'],
#   '16': ['Tataki',
#    'https://www.yelp.com/biz/tataki-san-francisco?osq=restaurants',
#    '4 star rating',
#    '1204 reviews',
#    '$$',
#    'Sushi Bars, Bars'],
#   '17': ['INDO',
#    'https://www.yelp.com/biz/indo-san-francisco?osq=restaurants',
#    '5 star rating',
#    '86 reviews',
#    '$$$',
#    'Indonesian'],
#   '18': ['Zero Zero',
#    'https://www.yelp.com/biz/zero-zero-san-francisco?osq=restaurants',
#    '4 star rating',
#    '3096 reviews',
#    '$$',
#    'Pizza, Italian, Cocktail Bars'],
#   '19': ['San Tung',
#    'https://www.yelp.com/biz/san-tung-san-francisco-2?osq=restaurants',
#    '4 star rating',
#    '6332 reviews',
#    '$$',
#    'Chinese, Chicken Wings, Noodles'],
#   '20': ['Brenda’s French Soul Food',
#    'https://www.yelp.com/biz/brendas-french-soul-food-san-francisco?osq=restaurants',
#    '4 star rating',
#    '10112 reviews',
#    '$$',
#    'Breakfast & Brunch, French, Soul Food'],
#   '21': ['Burma Superstar',
#    'https://www.yelp.com/biz/burma-superstar-san-francisco-2?osq=restaurants',
#    '4 star rating',
#    '6413 reviews',
#    '$$',
#    'Burmese'],
#   '22': ['Kitchen Story',
#    'https://www.yelp.com/biz/kitchen-story-san-francisco?osq=restaurants',
#    '4 star rating',
#    '2800 reviews',
#    '$$',
#    'Breakfast & Brunch, Asian Fusion, American (New)'],
#   '23': ['PPQ Dungeness Island',
#    'https://www.yelp.com/biz/ppq-dungeness-island-san-francisco-2?osq=restaurants',
#    '4 star rating',
#    '2887 reviews',
#    '$$',
#    'Seafood, Vietnamese, Asian Fusion'],
#   '24': ['Thanh Long',
#    'https://www.yelp.com/biz/thanh-long-san-francisco?osq=restaurants',
#    '4 star rating',
#    '2430 reviews',
#    '$$$',
#    'Seafood, Vietnamese'],
#   '25': ['Palm House',
#    'https://www.yelp.com/biz/palm-house-san-francisco?osq=restaurants',
#    '4 star rating',
#    '675 reviews',
#    '$$',
#    'Caribbean, Hawaiian, Venues & Event Spaces'],
#   '26': ['Fondue Cowboy',
#    'https://www.yelp.com/biz/fondue-cowboy-san-francisco?osq=restaurants',
#    '4 star rating',
#    '548 reviews',
#    '$$',
#    'Fondue, American (New)'],
#   '27': ['Bobo’s',
#    'https://www.yelp.com/biz/bobos-san-francisco-14?osq=restaurants',
#    '4 star rating',
#    '1982 reviews',
#    '$$$',
#    'Steakhouses, Seafood'],
#   '28': ['Marlowe',
#    'https://www.yelp.com/biz/marlowe-san-francisco-2?osq=restaurants',
#    '4 star rating',
#    '2571 reviews',
#    '$$',
#    'American (New), Brasseries'],
#   '29': ['Skool',
#    'https://www.yelp.com/biz/skool-san-francisco?osq=restaurants',
#    '4 star rating',
#    '1603 reviews',
#    '$$',
#    'Seafood, Japanese, Asian Fusion'],
#   '30': ['The Dorian',
#    'https://www.yelp.com/biz/the-dorian-san-francisco?osq=restaurants',
#    '4 star rating',
#    '439 reviews',
#    '$$',
#    'American (Traditional), Cocktail Bars, Gastropubs']},
#  'New York': {'1': ['Amélie',
#    'https://www.yelp.com/biz/am%C3%A9lie-new-york?osq=restaurants',
#    '4.5 star rating',
#    '2296 reviews',
#    '$$',
#    'French, Wine Bars'],
#   '2': ['Upstate',
#    'https://www.yelp.com/biz/upstate-new-york-2?osq=restaurants',
#    '4.5 star rating',
#    '1633 reviews',
#    '$$',
#    'Seafood, Wine Bars, Beer Bar'],
#   '3': ['The Wayland',
#    'https://www.yelp.com/biz/the-wayland-new-york?osq=restaurants',
#    '4.5 star rating',
#    '472 reviews',
#    '$$',
#    'Cocktail Bars, Music Venues, American (Traditional)'],
#   '4': ['Burger & Lobster',
#    'https://www.yelp.com/biz/burger-and-lobster-new-york-4?osq=restaurants',
#    '4 star rating',
#    '4692 reviews',
#    '$$',
#    'Seafood, Burgers, American (New)'],
#   '5': ['Hartley’s',
#    'https://www.yelp.com/biz/hartleys-brooklyn?osq=restaurants',
#    '5 star rating',
#    '54 reviews',
#    '$$',
#    'Irish Pub, Breakfast & Brunch'],
#   '6': ['Eataly Downtown',
#    'https://www.yelp.com/biz/eataly-downtown-new-york?osq=restaurants',
#    '3.5 star rating',
#    '740 reviews',
#    '$$',
#    'Grocery, Italian, Meat Shops'],
#   '7': ['886',
#    'https://www.yelp.com/biz/886-new-york?osq=restaurants',
#    '4 star rating',
#    '185 reviews',
#    '$$',
#    'Taiwanese'],
#   '8': ['LoveMama',
#    'https://www.yelp.com/biz/lovemama-new-york?osq=restaurants',
#    '4 star rating',
#    '3876 reviews',
#    '$$',
#    'Thai, Malaysian, Vietnamese'],
#   '9': ['Uglyduckling',
#    'https://www.yelp.com/biz/uglyduckling-brooklyn?osq=restaurants',
#    '4 star rating',
#    '411 reviews',
#    '$$',
#    'American (Traditional), Gastropubs'],
#   '10': ['Omakasa',
#    'https://www.yelp.com/biz/omakasa-new-york-8?osq=restaurants',
#    '4 star rating',
#    '62 reviews',
#    '$$',
#    'Asian Fusion, Japanese, American (New)'],
#   '11': ['Aunt Jake’s',
#    'https://www.yelp.com/biz/aunt-jakes-new-york?osq=restaurants',
#    '4 star rating',
#    '1009 reviews',
#    '$$',
#    'Italian, Wine Bars, Pasta Shops'],
#   '12': ['Tanner Smiths',
#    'https://www.yelp.com/biz/tanner-smiths-new-york-2?osq=restaurants',
#    '4 star rating',
#    '1340 reviews',
#    '$$',
#    'Cocktail Bars, American (New), Speakeasies'],
#   '13': ['Ipanema Restaurant',
#    'https://www.yelp.com/biz/ipanema-restaurant-new-york?osq=restaurants',
#    '4 star rating',
#    '1120 reviews',
#    '$$',
#    'Brazilian, Latin American, Portuguese'],
#   '14': ['Silver Factory',
#    'https://www.yelp.com/biz/silver-factory-brooklyn?osq=restaurants',
#    '4.5 star rating',
#    '129 reviews',
#    '$$',
#    'Korean, Bars'],
#   '15': ['Jacob’s Pickles',
#    'https://www.yelp.com/biz/jacobs-pickles-new-york?osq=restaurants',
#    '4 star rating',
#    '3457 reviews',
#    '$$',
#    'Comfort Food, Southern, American (Traditional)'],
#   '16': ['Bea',
#    'https://www.yelp.com/biz/bea-new-york?osq=restaurants',
#    '4 star rating',
#    '2078 reviews',
#    '$$',
#    'American (New), Cocktail Bars'],
#   '17': ['Boucherie West Village',
#    'https://www.yelp.com/biz/boucherie-west-village-new-york-3?osq=restaurants',
#    '4.5 star rating',
#    '872 reviews',
#    '$$$',
#    'French, Cocktail Bars, Steakhouses'],
#   '18': ['Carmine’s Italian Restaurant - Times Square',
#    'https://www.yelp.com/biz/carmines-italian-restaurant-times-square-new-york-5?osq=restaurants',
#    '4 star rating',
#    '3203 reviews',
#    '$$',
#    'Italian, Venues & Event Spaces, Seafood'],
#   '19': ['Bernie’s',
#    'https://www.yelp.com/biz/bernies-brooklyn?osq=restaurants',
#    '4.5 star rating',
#    '19 reviews',
#    'American (New), Beer Bar, Wine Bars',
#    'American (New),'],
#   '20': ['Trattoria Trecolori',
#    'https://www.yelp.com/biz/trattoria-trecolori-new-york?osq=restaurants',
#    '4 star rating',
#    '1944 reviews',
#    '$$',
#    'Italian'],
#   '21': ['Atrium Dumbo',
#    'https://www.yelp.com/biz/atrium-dumbo-brooklyn?osq=restaurants',
#    '3.5 star rating',
#    '572 reviews',
#    '$$',
#    'American (New), French'],
#   '22': ['Bijan’s',
#    'https://www.yelp.com/biz/bijans-brooklyn-2?osq=restaurants',
#    '4 star rating',
#    '460 reviews',
#    '$$',
#    'American (New), Cocktail Bars'],
#   '23': ['Midwinter Kitchen',
#    'https://www.yelp.com/biz/midwinter-kitchen-new-york?osq=restaurants',
#    '4.5 star rating',
#    '447 reviews',
#    '$$',
#    'American (New)'],
#   '24': ['Tava Turkish Mediterranean',
#    'https://www.yelp.com/biz/tava-turkish-mediterranean-brooklyn?osq=restaurants',
#    '5 star rating',
#    '103 reviews',
#    '$$',
#    'Turkish, Mediterranean'],
#   '25': ['The MasalaWala',
#    'https://www.yelp.com/biz/the-masalawala-new-york-2?osq=restaurants',
#    '4.5 star rating',
#    '1281 reviews',
#    '$$',
#    'Indian, Pakistani'],
#   '26': ['Angeletto Restaurant',
#    'https://www.yelp.com/biz/angeletto-restaurant-new-york?osq=restaurants',
#    '4.5 star rating',
#    '89 reviews',
#    '$$',
#    'Italian'],
#   '27': ['Concrete',
#    'https://www.yelp.com/biz/concrete-brooklyn?osq=restaurants',
#    '4 star rating',
#    '30 reviews',
#    '$$',
#    'Bars, Breakfast & Brunch, Sicilian'],
#   '28': ['Balzem',
#    'https://www.yelp.com/biz/balzem-new-york?osq=restaurants',
#    '4 star rating',
#    '358 reviews',
#    '$$',
#    'Mediterranean, Tapas/Small Plates, Wine Bars'],
#   '29': ['Root & Bone',
#    'https://www.yelp.com/biz/root-and-bone-new-york?osq=restaurants',
#    '4 star rating',
#    '1435 reviews',
#    '$$',
#    'Southern, Comfort Food, Desserts'],
#   '30': ['District Social',
#    'https://www.yelp.com/biz/district-social-new-york?osq=restaurants',
#    '4 star rating',
#    '507 reviews',
#    '$$',
#    'Bars, American (New)']}}

# %%
all_result['San Francisco']['10'] #finds 10th place restaurant in SF
# Out:
# ['Hog Island Oyster Co',
#  'https://www.yelp.com/biz/hog-island-oyster-co-san-francisco?osq=restaurants',
#  '4.5 star rating',
#  '5477 reviews',
#  '$$',
#  'Seafood, Seafood Markets, Live/Raw Food']
